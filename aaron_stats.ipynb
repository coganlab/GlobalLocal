# %%
###
import sys
print(sys.path)
sys.path.append("C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/") #need to do this cuz otherwise ieeg isn't added to path...

from ieeg.navigate import channel_outlier_marker, trial_ieeg, crop_empty_data, \
    outliers_to_nan
from ieeg.io import raw_from_layout, get_data
from ieeg.timefreq.utils import crop_pad
from ieeg.timefreq import gamma
from ieeg.calc.scaling import rescale
import mne
import os
import numpy as np
from ieeg.calc.reshape import make_data_same
from ieeg.calc.stats import time_perm_cluster

from misc_functions import calculate_RTs, save_channels_to_file, save_sig_chans
import matplotlib.pyplot as plt


def get_baseline(inst: mne.io.BaseRaw, base_times: tuple[float, float]):
    inst = inst.copy()
    inst.load_data()
    ch_type = inst.get_channel_types(only_data_chs=True)[0]
    inst.set_eeg_reference(ref_channels="average", ch_type=ch_type)

    adjusted_base_times = [base_times[0] - 0.5, base_times[1] + 0.5]
    trials = trial_ieeg(inst, "experimentStart", adjusted_base_times,
                        preload=True)
    # outliers_to_nan(trials, outliers=10)
    HG_base = gamma.extract(trials, copy=False, n_jobs=1)
    crop_pad(HG_base, "0.5s")
    del inst
    return HG_base


def plot_HG_and_stats(sub, task, output_name, event=None, times=(-1, 1.5),
                      base_times=(-0.5, 0), LAB_root=None, channels=None,
                      full_trial_base=False):
    """
    Plot high gamma (HG) and statistics for a given subject and task using specified event.

    Parameters:
    - sub (str): The subject identifier.
    - task (str): The task identifier.
    - output_name (str): The name for the output files.
    - event (str, optional): Event name to process. Defaults to None.
    - times (tuple, optional): A tuple indicating the start and end times for processing. Defaults to (-1, 1.5).
    - base_times (tuple, optional): A tuple indicating the start and end base times for processing. Defaults to (-0.5, 0).
    - LAB_root (str, optional): The root directory for the lab. Will be determined based on OS if not provided. Defaults to None.
    - channels (list of strings, optional): The channels to plot and get stats for. Default is all channels.
    - full_trial_base (boolean): Whether to use the full trial as the baseline period. Default is False.
    This function will process the provided event for a given subject and task.
    High gamma (HG) will be computed, and statistics will be calculated and plotted.
    The results will be saved to output files.
    """
    pass


sub = 'D0057'
task = 'GlobalLocal'
output_name = "stimulusCongruent_experimentStartBase1secTo101Sec"
events = ["Stimulus/c25","Stimulus/c75"]
times = (-1, 1.5)
base_times = (1, 101)
LAB_root = None
channels = None
full_trial_base = False

if LAB_root is None:
    HOME = os.path.expanduser("~")
    if os.name == 'nt':  # windows
        LAB_root = os.path.join(HOME, "Box", "CoganLab")
    else:  # mac
        LAB_root = os.path.join(HOME, "Library", "CloudStorage", "Box-Box",
                                "CoganLab")

layout = get_data(task, root=LAB_root)
filt = raw_from_layout(layout.derivatives['derivatives/clean'], subject=sub,
                       extension='.edf', desc='clean', preload=False)
save_dir = os.path.join(layout.root, 'derivatives', 'freqFilt', 'figs', sub)
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

###

good = crop_empty_data(filt)
# %%

print(f"good channels before dropping bads: {len(good.ch_names)}")
print(f"filt channels before dropping bads: {len(filt.ch_names)}")

good.info['bads'] = channel_outlier_marker(good, 3, 2)
print("Bad channels in 'good':", good.info['bads'])

filt.drop_channels(good.info['bads'])  # this has to come first cuz if you drop from good first, then good.info['bads'] is just empty
good.drop_channels(good.info['bads'])

print("Bad channels in 'good' after dropping once:", good.info['bads'])

print(f"good channels after dropping bads: {len(good.ch_names)}")
print(f"filt channels after dropping bads: {len(filt.ch_names)}")

HG_base = get_baseline(filt, base_times)
good.load_data()

# If channels is None, use all channels
if channels is None:
    channels = good.ch_names
else:
    # Validate the provided channels
    invalid_channels = [ch for ch in channels if ch not in good.ch_names]
    if invalid_channels:
        raise ValueError(
            f"The following channels are not valid: {invalid_channels}")

    # Use only the specified channels
    good.pick_channels(channels)

ch_type = filt.get_channel_types(only_data_chs=True)[0]
good.set_eeg_reference(ref_channels="average", ch_type=ch_type)

all_epochs_list = []

for event in events:
# Epoching and HG extraction for each specified event. Then concatenate all trials epochs objects together (do Stimulus/c25 and Stimulus/c75 for example, and combine to get all congruent trials)
    times_adj = [times[0] - 0.5, times[1] + 0.5]
    trials = trial_ieeg(good, event, times_adj, preload=True,
                        reject_by_annotation=False)
    all_epochs_list.append(trials)

# Concatenate all trials
all_trials = mne.concatenate_epochs(all_epochs_list)

outliers_to_nan(all_trials, outliers=10)
HG_ev1 = gamma.extract(all_trials, copy=False, n_jobs=1)
crop_pad(HG_ev1, "0.5s")
HG_ev1_rescaled = rescale(HG_ev1, HG_base, copy=True, mode='zscore')

HG_base.decimate(2)
HG_ev1.decimate(2)
RTs, skipped = calculate_RTs(good)
avg_RT = np.median(RTs)

HG_ev1_evoke = HG_ev1.average(method=lambda x: np.nanmean(x, axis=0))
HG_ev1_evoke_rescaled = HG_ev1_rescaled.average(method=lambda x: np.nanmean(x, axis=0))

if event == "Stimulus":
    print('plotting stimulus')
    fig = HG_ev1_evoke_rescaled.plot(unit=False, scalings=dict(sEEG=1)) #this line is not finishing...
    print('plotted')
    for ax in fig.axes:
        ax.axvline(x=avg_RT, color='r', linestyle='--')
    print('about to save')
    fig.savefig(save_dir + '_HG_ev1_Stimulus_zscore.png')
    print('saved')
else:
    print('about to plot if not stimulus')
    fig = HG_ev1_evoke_rescaled.plot(unit=False, scalings=dict(sEEG=1))
    print('plotted non stimulus')
    fig.savefig(save_dir + f'_HG_ev1_{output_name}_zscore.png')

###
print(f"Shape of HG_ev1._data: {HG_ev1._data.shape}")
print(f"Shape of HG_base._data: {HG_base._data.shape}")

sig1 = HG_ev1._data
sig2 = HG_base._data
sig2 = make_data_same(sig2, sig1.shape)
print(f"Shape of sig1: {sig1.shape}")
print(f"Shape of sig2: {sig2.shape}")

mat = time_perm_cluster(sig1, sig2, 0.05, n_jobs=6, ignore_adjacency=1)
fig = plt.figure()
plt.imshow(mat, aspect='auto')
fig.savefig(save_dir + f'_{output_name}_stats.png', dpi=300)

channels = good.ch_names

#save channels with their indices 
save_channels_to_file(channels, sub, task, save_dir)

# save significant channels to a json
save_sig_chans(f'{output_name}', mat, channels, sub, save_dir)
# Out:
# ['c:\\Users\\jz421\\Desktop\\GlobalLocal', 'C:\\Users\\jz421\\Desktop\\GlobalLocal\\IEEG_Pipelines', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\python311.zip', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\DLLs', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg', '', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\win32', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\Pythonwin', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/']
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-01_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-01_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-01_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-02_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-02_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-02_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-03_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-03_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-03_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-04_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-04_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-04_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 226 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# good channels before dropping bads: 178
# filt channels before dropping bads: 178
# outlier round 1 channels: ['RAMT8']
# outlier round 2 channels: ['RAMT8', 'RPI16']
# outlier round 2 channels: ['RAMT8', 'RPI16', 'LAMT12']
# Bad channels in 'good': ['RAMT8', 'RPI16', 'LAMT12']
# Bad channels in 'good' after dropping once: []
# good channels after dropping bads: 175
# filt channels after dropping bads: 175
# Reading 0 ... 8243199  =      0.000 ...  4025.000 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n25', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n25', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 206849 original time points ...
# 0 bad epochs dropped
# 100%|██████████| 1/1 [00:54<00:00, 54.67s/it]
# Reading 0 ... 5983997  =      0.000 ...  2921.874 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n25', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n25', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 168 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 168 events and 7169 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n25', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n25', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 56 events and 7169 original time points ...
# 0 bad epochs dropped
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\2186321786.py:134: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_trials = mne.concatenate_epochs(all_epochs_list)
# Not setting metadata
# 224 matching events found
# No baseline correction applied
# 100%|██████████| 224/224 [04:32<00:00,  1.22s/it]
# Applying baseline correction (mode: zscore)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\2186321786.py:141: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_base.decimate(2)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\2186321786.py:142: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_ev1.decimate(2)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# about to plot if not stimulus
# plotted non stimulus
# Shape of HG_ev1._data: (224, 175, 2561)
# Shape of HG_base._data: (1, 175, 102401)
# Shape of sig1: (224, 175, 2561)
# Shape of sig2: (39, 175, 2561)
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   28.9s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   29.0s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:   29.7s
# [Parallel(n_jobs=6)]: Done   7 tasks      | elapsed:   53.7s
# [Parallel(n_jobs=6)]: Done   8 tasks      | elapsed:   54.0s
# [Parallel(n_jobs=6)]: Done   9 tasks      | elapsed:   54.3s
# [Parallel(n_jobs=6)]: Done  10 tasks      | elapsed:   54.4s
# [Parallel(n_jobs=6)]: Done  11 tasks      | elapsed:   54.5s
# [Parallel(n_jobs=6)]: Done  12 tasks      | elapsed:   55.2s
# [Parallel(n_jobs=6)]: Done  13 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  14 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  15 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  16 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  17 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  18 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  19 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  21 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  22 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  23 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  24 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  25 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=6)]: Done  26 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=6)]: Done  27 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  28 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  29 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  30 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  31 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  32 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  33 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  34 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  35 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  36 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  37 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  39 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  40 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  41 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  43 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=6)]: Done  44 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=6)]: Done  45 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  46 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  47 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  48 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  49 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=6)]: Done  50 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=6)]: Done  51 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=6)]: Done  52 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=6)]: Done  53 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=6)]: Done  54 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=6)]: Done  55 tasks      | elapsed:  3.9min
# [Parallel(n_jobs=6)]: Done  56 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=6)]: Done  57 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=6)]: Done  58 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=6)]: Done  59 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=6)]: Done  60 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=6)]: Done  61 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=6)]: Done  62 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=6)]: Done  63 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=6)]: Done  64 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  65 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  66 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  67 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=6)]: Done  68 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=6)]: Done  69 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=6)]: Done  70 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=6)]: Done  71 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=6)]: Done  72 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=6)]: Done  73 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=6)]: Done  74 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=6)]: Done  75 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=6)]: Done  76 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=6)]: Done  77 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=6)]: Done  78 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=6)]: Done  79 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=6)]: Done  80 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=6)]: Done  81 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=6)]: Done  82 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done  83 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done  84 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done  85 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=6)]: Done  86 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=6)]: Done  87 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=6)]: Done  88 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=6)]: Done  89 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=6)]: Done  90 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=6)]: Done  91 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=6)]: Done  92 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=6)]: Done  93 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done  94 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=6)]: Done  95 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=6)]: Done  96 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=6)]: Done  97 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=6)]: Done  98 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=6)]: Done  99 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=6)]: Done 100 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done 101 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done 102 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done 103 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done 104 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=6)]: Done 105 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=6)]: Done 106 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=6)]: Done 107 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=6)]: Done 108 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=6)]: Done 109 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=6)]: Done 110 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=6)]: Done 111 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=6)]: Done 112 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=6)]: Done 113 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=6)]: Done 114 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=6)]: Done 115 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=6)]: Done 116 tasks      | elapsed:  8.0min
# [Parallel(n_jobs=6)]: Done 117 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done 118 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=6)]: Done 119 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=6)]: Done 120 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=6)]: Done 121 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=6)]: Done 122 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=6)]: Done 123 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=6)]: Done 124 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=6)]: Done 125 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=6)]: Done 126 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=6)]: Done 127 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=6)]: Done 128 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=6)]: Done 129 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done 130 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=6)]: Done 131 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=6)]: Done 132 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=6)]: Done 133 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=6)]: Done 134 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=6)]: Done 135 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done 136 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=6)]: Done 137 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=6)]: Done 138 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=6)]: Done 139 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=6)]: Done 140 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=6)]: Done 141 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=6)]: Done 142 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 143 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 144 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 145 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 146 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=6)]: Done 147 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=6)]: Done 148 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=6)]: Done 149 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=6)]: Done 150 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=6)]: Done 151 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 152 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 153 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 154 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=6)]: Done 155 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=6)]: Done 156 tasks      | elapsed: 10.8min
# [Parallel(n_jobs=6)]: Done 157 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 158 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 159 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 160 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=6)]: Done 161 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=6)]: Done 162 tasks      | elapsed: 11.2min
# [Parallel(n_jobs=6)]: Done 163 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=6)]: Done 164 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=6)]: Done 169 out of 175 | elapsed: 11.7min remaining:   24.8s
# [Parallel(n_jobs=6)]: Done 175 out of 175 | elapsed: 11.9min finished
# Saved channel names and indices to C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\freqFilt\figs\D0057\channels_D0057_GlobalLocal.txt
# Saved significant channels for subject D0057 and mask stimulusCongruent_experimentStartBase1secTo101Sec to C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\freqFilt\figs\D0057\sig_chans_D0057_stimulusCongruent_experimentStartBase1secTo101Sec.json

# %%
###
import sys
print(sys.path)
sys.path.append("C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/") #need to do this cuz otherwise ieeg isn't added to path...

from ieeg.navigate import channel_outlier_marker, trial_ieeg, crop_empty_data, \
    outliers_to_nan
from ieeg.io import raw_from_layout, get_data
from ieeg.timefreq.utils import crop_pad
from ieeg.timefreq import gamma
from ieeg.calc.scaling import rescale
import mne
import os
import numpy as np
from ieeg.calc.reshape import make_data_same
from ieeg.calc.stats import time_perm_cluster

from misc_functions import calculate_RTs, save_channels_to_file, save_sig_chans
import matplotlib.pyplot as plt


def get_baseline(inst: mne.io.BaseRaw, base_times: tuple[float, float]):
    inst = inst.copy()
    inst.load_data()
    ch_type = inst.get_channel_types(only_data_chs=True)[0]
    inst.set_eeg_reference(ref_channels="average", ch_type=ch_type)

    adjusted_base_times = [base_times[0] - 0.5, base_times[1] + 0.5]
    trials = trial_ieeg(inst, "experimentStart", adjusted_base_times,
                        preload=True)
    # outliers_to_nan(trials, outliers=10)
    HG_base = gamma.extract(trials, copy=False, n_jobs=1)
    crop_pad(HG_base, "0.5s")
    del inst
    return HG_base


def plot_HG_and_stats(sub, task, output_name, event=None, times=(-1, 1.5),
                      base_times=(-0.5, 0), LAB_root=None, channels=None,
                      full_trial_base=False):
    """
    Plot high gamma (HG) and statistics for a given subject and task using specified event.

    Parameters:
    - sub (str): The subject identifier.
    - task (str): The task identifier.
    - output_name (str): The name for the output files.
    - event (str, optional): Event name to process. Defaults to None.
    - times (tuple, optional): A tuple indicating the start and end times for processing. Defaults to (-1, 1.5).
    - base_times (tuple, optional): A tuple indicating the start and end base times for processing. Defaults to (-0.5, 0).
    - LAB_root (str, optional): The root directory for the lab. Will be determined based on OS if not provided. Defaults to None.
    - channels (list of strings, optional): The channels to plot and get stats for. Default is all channels.
    - full_trial_base (boolean): Whether to use the full trial as the baseline period. Default is False.
    This function will process the provided event for a given subject and task.
    High gamma (HG) will be computed, and statistics will be calculated and plotted.
    The results will be saved to output files.
    """
    pass

subjects = ['D0057', 'D0059', 'D0063', 'D0065', 'D0069', 'D0071']
for sub in subjects:
    sub = sub
    output_name = "stimulusIncongruent_experimentStartBase1secTo101Sec"
    events = ["Stimulus/i25","Stimulus/i75"]
    times = (-1, 1.5)
    base_times = (1, 101)
    LAB_root = None
    channels = None
    full_trial_base = False

    if LAB_root is None:
        HOME = os.path.expanduser("~")
        if os.name == 'nt':  # windows
            LAB_root = os.path.join(HOME, "Box", "CoganLab")
        else:  # mac
            LAB_root = os.path.join(HOME, "Library", "CloudStorage", "Box-Box",
                                    "CoganLab")

    layout = get_data(task, root=LAB_root)
    filt = raw_from_layout(layout.derivatives['derivatives/clean'], subject=sub,
                        extension='.edf', desc='clean', preload=False)
    save_dir = os.path.join(layout.root, 'derivatives', 'freqFilt', 'figs', sub)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    ###

    good = crop_empty_data(filt)
    # %%

    print(f"good channels before dropping bads: {len(good.ch_names)}")
    print(f"filt channels before dropping bads: {len(filt.ch_names)}")

    good.info['bads'] = channel_outlier_marker(good, 3, 2)
    print("Bad channels in 'good':", good.info['bads'])

    filt.drop_channels(good.info['bads'])  # this has to come first cuz if you drop from good first, then good.info['bads'] is just empty
    good.drop_channels(good.info['bads'])

    print("Bad channels in 'good' after dropping once:", good.info['bads'])

    print(f"good channels after dropping bads: {len(good.ch_names)}")
    print(f"filt channels after dropping bads: {len(filt.ch_names)}")

    HG_base = get_baseline(filt, base_times)
    good.load_data()

    # If channels is None, use all channels
    if channels is None:
        channels = good.ch_names
    else:
        # Validate the provided channels
        invalid_channels = [ch for ch in channels if ch not in good.ch_names]
        if invalid_channels:
            raise ValueError(
                f"The following channels are not valid: {invalid_channels}")

        # Use only the specified channels
        good.pick_channels(channels)

    ch_type = filt.get_channel_types(only_data_chs=True)[0]
    good.set_eeg_reference(ref_channels="average", ch_type=ch_type)

    all_epochs_list = []

    for event in events:
    # Epoching and HG extraction for each specified event. Then concatenate all trials epochs objects together (do Stimulus/c25 and Stimulus/c75 for example, and combine to get all congruent trials)
        times_adj = [times[0] - 0.5, times[1] + 0.5]
        trials = trial_ieeg(good, event, times_adj, preload=True,
                            reject_by_annotation=False)
        all_epochs_list.append(trials)

    # Concatenate all trials
    all_trials = mne.concatenate_epochs(all_epochs_list)

    outliers_to_nan(all_trials, outliers=10)
    HG_ev1 = gamma.extract(all_trials, copy=False, n_jobs=1)
    crop_pad(HG_ev1, "0.5s")
    HG_ev1_rescaled = rescale(HG_ev1, HG_base, copy=True, mode='zscore')

    HG_base.decimate(2)
    HG_ev1.decimate(2)
    RTs, skipped = calculate_RTs(good)
    avg_RT = np.median(RTs)

    HG_ev1_evoke = HG_ev1.average(method=lambda x: np.nanmean(x, axis=0))
    HG_ev1_evoke_rescaled = HG_ev1_rescaled.average(method=lambda x: np.nanmean(x, axis=0))

    if event == "Stimulus":
        print('plotting stimulus')
        fig = HG_ev1_evoke_rescaled.plot(unit=False, scalings=dict(sEEG=1)) #this line is not finishing...
        print('plotted')
        for ax in fig.axes:
            ax.axvline(x=avg_RT, color='r', linestyle='--')
        print('about to save')
        fig.savefig(save_dir + '_HG_ev1_Stimulus_zscore.png')
        print('saved')
    else:
        print('about to plot if not stimulus')
        fig = HG_ev1_evoke_rescaled.plot(unit=False, scalings=dict(sEEG=1))
        print('plotted non stimulus')
        fig.savefig(save_dir + f'_HG_ev1_{output_name}_zscore.png')

    ###
    print(f"Shape of HG_ev1._data: {HG_ev1._data.shape}")
    print(f"Shape of HG_base._data: {HG_base._data.shape}")

    sig1 = HG_ev1._data
    sig2 = HG_base._data
    sig2 = make_data_same(sig2, sig1.shape)
    print(f"Shape of sig1: {sig1.shape}")
    print(f"Shape of sig2: {sig2.shape}")

    mat = time_perm_cluster(sig1, sig2, 0.05, n_jobs=6, ignore_adjacency=1)
    fig = plt.figure()
    plt.imshow(mat, aspect='auto')
    fig.savefig(save_dir + f'_{output_name}_stats.png', dpi=300)

    channels = good.ch_names

    #save channels with their indices 
    save_channels_to_file(channels, sub, task, save_dir)

    # save significant channels to a json
    save_sig_chans(f'{output_name}', mat, channels, sub, save_dir)
# Out:
# ['c:\\Users\\jz421\\Desktop\\GlobalLocal', 'C:\\Users\\jz421\\Desktop\\GlobalLocal\\IEEG_Pipelines', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\python311.zip', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\DLLs', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg', '', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\win32', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\Pythonwin', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/']
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-01_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-01_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-01_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-02_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-02_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-02_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-03_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-03_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-03_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-04_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-04_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_task-GlobalLocal_acq-01_run-04_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0057\ieeg\sub-D0057_acq-01_space-ACPC_electrodes.tsv.
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 226 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (179) does not match the number of channels in the raw data file (178). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# good channels before dropping bads: 178
# filt channels before dropping bads: 178
# outlier round 1 channels: ['RAMT8']
# outlier round 2 channels: ['RAMT8', 'RPI16']
# outlier round 2 channels: ['RAMT8', 'RPI16', 'LAMT12']
# Bad channels in 'good': ['RAMT8', 'RPI16', 'LAMT12']
# Bad channels in 'good' after dropping once: []
# good channels after dropping bads: 175
# filt channels after dropping bads: 175
# Reading 0 ... 8243199  =      0.000 ...  4025.000 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n25', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n25', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 206849 original time points ...
# 0 bad epochs dropped
# 100%|██████████| 1/1 [00:54<00:00, 54.98s/it]
# Reading 0 ... 5983997  =      0.000 ...  2921.874 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n25', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n25', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 56 events and 7169 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n25', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n25', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 168 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 168 events and 7169 original time points ...
# 0 bad epochs dropped
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\4024603525.py:134: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_trials = mne.concatenate_epochs(all_epochs_list)
# Not setting metadata
# 224 matching events found
# No baseline correction applied
# 100%|██████████| 224/224 [04:29<00:00,  1.20s/it]
# Applying baseline correction (mode: zscore)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\4024603525.py:141: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_base.decimate(2)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\4024603525.py:142: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_ev1.decimate(2)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# about to plot if not stimulus
# plotted non stimulus
# Shape of HG_ev1._data: (224, 175, 2561)
# Shape of HG_base._data: (1, 175, 102401)
# Shape of sig1: (224, 175, 2561)
# Shape of sig2: (39, 175, 2561)
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   27.6s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   27.7s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:   27.8s
# [Parallel(n_jobs=6)]: Done   7 tasks      | elapsed:   51.6s
# [Parallel(n_jobs=6)]: Done   8 tasks      | elapsed:   52.3s
# [Parallel(n_jobs=6)]: Done   9 tasks      | elapsed:   52.5s
# [Parallel(n_jobs=6)]: Done  10 tasks      | elapsed:   52.7s
# [Parallel(n_jobs=6)]: Done  11 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=6)]: Done  12 tasks      | elapsed:   52.8s
# [Parallel(n_jobs=6)]: Done  13 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  14 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  15 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  16 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  17 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  18 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  19 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  21 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  22 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  23 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  24 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  25 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=6)]: Done  26 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=6)]: Done  27 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  28 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  29 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  30 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  31 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  32 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  33 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  34 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  35 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  36 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  37 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  39 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  40 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  41 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  43 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=6)]: Done  44 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=6)]: Done  45 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=6)]: Done  46 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  47 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  48 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  49 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=6)]: Done  50 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=6)]: Done  51 tasks      | elapsed:  3.7min
# [Parallel(n_jobs=6)]: Done  52 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=6)]: Done  53 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=6)]: Done  54 tasks      | elapsed:  3.8min
# [Parallel(n_jobs=6)]: Done  55 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  56 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  57 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=6)]: Done  58 tasks      | elapsed:  4.1min
# [Parallel(n_jobs=6)]: Done  59 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=6)]: Done  60 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=6)]: Done  61 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=6)]: Done  62 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=6)]: Done  63 tasks      | elapsed:  4.4min
# [Parallel(n_jobs=6)]: Done  64 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=6)]: Done  65 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  66 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  67 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=6)]: Done  68 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=6)]: Done  69 tasks      | elapsed:  4.8min
# [Parallel(n_jobs=6)]: Done  70 tasks      | elapsed:  4.9min
# [Parallel(n_jobs=6)]: Done  71 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=6)]: Done  72 tasks      | elapsed:  5.0min
# [Parallel(n_jobs=6)]: Done  73 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=6)]: Done  74 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=6)]: Done  75 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=6)]: Done  76 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=6)]: Done  77 tasks      | elapsed:  5.3min
# [Parallel(n_jobs=6)]: Done  78 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=6)]: Done  79 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=6)]: Done  80 tasks      | elapsed:  5.5min
# [Parallel(n_jobs=6)]: Done  81 tasks      | elapsed:  5.6min
# [Parallel(n_jobs=6)]: Done  82 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=6)]: Done  83 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=6)]: Done  84 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=6)]: Done  85 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done  86 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=6)]: Done  87 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=6)]: Done  88 tasks      | elapsed:  6.0min
# [Parallel(n_jobs=6)]: Done  89 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=6)]: Done  90 tasks      | elapsed:  6.1min
# [Parallel(n_jobs=6)]: Done  91 tasks      | elapsed:  6.2min
# [Parallel(n_jobs=6)]: Done  92 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=6)]: Done  93 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=6)]: Done  94 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=6)]: Done  95 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done  96 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done  97 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=6)]: Done  98 tasks      | elapsed:  6.6min
# [Parallel(n_jobs=6)]: Done  99 tasks      | elapsed:  6.7min
# [Parallel(n_jobs=6)]: Done 100 tasks      | elapsed:  6.8min
# [Parallel(n_jobs=6)]: Done 101 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=6)]: Done 102 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=6)]: Done 103 tasks      | elapsed:  6.9min
# [Parallel(n_jobs=6)]: Done 104 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=6)]: Done 105 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=6)]: Done 106 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done 107 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=6)]: Done 108 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=6)]: Done 109 tasks      | elapsed:  7.3min
# [Parallel(n_jobs=6)]: Done 110 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=6)]: Done 111 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=6)]: Done 112 tasks      | elapsed:  7.5min
# [Parallel(n_jobs=6)]: Done 113 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=6)]: Done 114 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=6)]: Done 115 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=6)]: Done 116 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=6)]: Done 117 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=6)]: Done 118 tasks      | elapsed:  7.9min
# [Parallel(n_jobs=6)]: Done 119 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done 120 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done 121 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done 122 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done 123 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done 124 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=6)]: Done 125 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=6)]: Done 126 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=6)]: Done 127 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=6)]: Done 128 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=6)]: Done 129 tasks      | elapsed:  8.5min
# [Parallel(n_jobs=6)]: Done 130 tasks      | elapsed:  8.6min
# [Parallel(n_jobs=6)]: Done 131 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done 132 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done 133 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done 134 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done 135 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done 136 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=6)]: Done 137 tasks      | elapsed:  9.2min
# [Parallel(n_jobs=6)]: Done 138 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done 139 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done 140 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done 141 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done 142 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done 143 tasks      | elapsed:  9.6min
# [Parallel(n_jobs=6)]: Done 144 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=6)]: Done 145 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=6)]: Done 146 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=6)]: Done 147 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=6)]: Done 148 tasks      | elapsed:  9.7min
# [Parallel(n_jobs=6)]: Done 149 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 150 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=6)]: Done 151 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=6)]: Done 152 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=6)]: Done 153 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=6)]: Done 154 tasks      | elapsed: 10.1min
# [Parallel(n_jobs=6)]: Done 155 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=6)]: Done 156 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 157 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 158 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 159 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 160 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 161 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=6)]: Done 162 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 163 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 164 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 169 out of 175 | elapsed: 11.3min remaining:   23.9s
# [Parallel(n_jobs=6)]: Done 175 out of 175 | elapsed: 11.5min finished
# Saved channel names and indices to C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\freqFilt\figs\D0057\channels_D0057_GlobalLocal.txt
# Saved significant channels for subject D0057 and mask stimulusIncongruent_experimentStartBase1secTo101Sec to C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\freqFilt\figs\D0057\sig_chans_D0057_stimulusIncongruent_experimentStartBase1secTo101Sec.json
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-01_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-01_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-01_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-02_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (185) does not match the number of channels in the raw data file (184). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-02_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-02_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-03_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (185) does not match the number of channels in the raw data file (184). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-03_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-03_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-04_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (185) does not match the number of channels in the raw data file (184). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-04_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_task-GlobalLocal_acq-01_run-04_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0059\ieeg\sub-D0059_acq-01_space-ACPC_electrodes.tsv.
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 226 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (185) does not match the number of channels in the raw data file (184). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# good channels before dropping bads: 184
# filt channels before dropping bads: 184
# outlier round 1 channels: ['LMPF15']
# outlier round 2 channels: ['LMPF15', 'LASP3']
# outlier round 2 channels: ['LMPF15', 'LASP3', 'LASP5']
# outlier round 2 channels: ['LMPF15', 'LASP3', 'LASP5', 'LASP6']
# outlier round 2 channels: ['LMPF15', 'LASP3', 'LASP5', 'LASP6', 'LMPT2']
# outlier round 2 channels: ['LMPF15', 'LASP3', 'LASP5', 'LASP6', 'LMPT2', 'LPT16']
# Bad channels in 'good': ['LMPF15', 'LASP3', 'LASP5', 'LASP6', 'LMPT2', 'LPT16']
# Bad channels in 'good' after dropping once: []
# good channels after dropping bads: 178
# filt channels after dropping bads: 178
# Reading 0 ... 8769535  =      0.000 ...  4282.000 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/n25', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/n25', 'Response/i25/n75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/n25', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n25', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 206849 original time points ...
# 0 bad epochs dropped
# 100%|██████████| 1/1 [00:55<00:00, 55.23s/it]
# Reading 0 ... 6582517  =      0.000 ...  3214.120 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/n25', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/n25', 'Response/i25/n75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/n25', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n25', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 56 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 56 events and 7169 original time points ...
# 0 bad epochs dropped
# Used Annotations descriptions: ['Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/n25', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/n25', 'Response/i25/n75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/n75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/n25', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/n25', 'Stimulus/i25/n75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/n75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 168 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 168 events and 7169 original time points ...
# 0 bad epochs dropped
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\4024603525.py:134: RuntimeWarning: Concatenation of Annotations within Epochs is not supported yet. All annotations will be dropped.
#   all_trials = mne.concatenate_epochs(all_epochs_list)
# Not setting metadata
# 224 matching events found
# No baseline correction applied
# 100%|██████████| 224/224 [04:45<00:00,  1.27s/it]
# Applying baseline correction (mode: zscore)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\4024603525.py:141: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_base.decimate(2)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\4024603525.py:142: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_ev1.decimate(2)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# about to plot if not stimulus
# plotted non stimulus
# Shape of HG_ev1._data: (224, 178, 2561)
# Shape of HG_base._data: (1, 178, 102401)
# Shape of sig1: (224, 178, 2561)
# Shape of sig2: (39, 178, 2561)
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   25.3s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   26.2s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   26.3s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   26.4s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:   26.6s
# [Parallel(n_jobs=6)]: Done   7 tasks      | elapsed:   49.7s
# [Parallel(n_jobs=6)]: Done   8 tasks      | elapsed:   49.8s
# [Parallel(n_jobs=6)]: Done   9 tasks      | elapsed:   50.1s
# [Parallel(n_jobs=6)]: Done  10 tasks      | elapsed:   50.5s
# [Parallel(n_jobs=6)]: Done  11 tasks      | elapsed:   50.9s
# [Parallel(n_jobs=6)]: Done  12 tasks      | elapsed:   51.2s
# [Parallel(n_jobs=6)]: Done  13 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  14 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  15 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=6)]: Done  16 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=6)]: Done  17 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=6)]: Done  18 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=6)]: Done  19 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  21 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  22 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  23 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  24 tasks      | elapsed:  1.8min
# [Parallel(n_jobs=6)]: Done  25 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=6)]: Done  26 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=6)]: Done  27 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  28 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  29 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  30 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=6)]: Done  31 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  32 tasks      | elapsed:  2.5min
# [Parallel(n_jobs=6)]: Done  33 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  34 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  35 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  36 tasks      | elapsed:  2.6min
# [Parallel(n_jobs=6)]: Done  37 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  39 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  40 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  41 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=6)]: Done  43 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=6)]: Done  44 tasks      | elapsed:  3.2min
# [Parallel(n_jobs=6)]: Done  45 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=6)]: Done  46 tasks      | elapsed:  3.3min
# [Parallel(n_jobs=6)]: Done  47 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  48 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  49 tasks      | elapsed:  3.6min
# [Parallel(n_jobs=6)]: Done  50 tasks      | elapsed:  3.6min

# %%
###
import sys
print(sys.path)
sys.path.append("C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/") #need to do this cuz otherwise ieeg isn't added to path...

from ieeg.navigate import channel_outlier_marker, trial_ieeg, crop_empty_data, \
    outliers_to_nan
from ieeg.io import raw_from_layout, get_data
from ieeg.timefreq.utils import crop_pad
from ieeg.timefreq import gamma
from ieeg.calc.scaling import rescale
import mne
import os
import numpy as np
from ieeg.calc.reshape import make_data_same
from ieeg.calc.stats import time_perm_cluster

from misc_functions import calculate_RTs, save_channels_to_file, save_sig_chans
import matplotlib.pyplot as plt


def get_baseline(inst: mne.io.BaseRaw, base_times: tuple[float, float]):
    inst = inst.copy()
    inst.load_data()
    ch_type = inst.get_channel_types(only_data_chs=True)[0]
    inst.set_eeg_reference(ref_channels="average", ch_type=ch_type)

    adjusted_base_times = [base_times[0] - 0.5, base_times[1] + 0.5]
    trials = trial_ieeg(inst, "experimentStart", adjusted_base_times,
                        preload=True)
    # outliers_to_nan(trials, outliers=10)
    HG_base = gamma.extract(trials, copy=False, n_jobs=1)
    crop_pad(HG_base, "0.5s")
    del inst
    return HG_base


def plot_HG_and_stats(sub, task, output_name, event=None, times=(-1, 1.5),
                      base_times=(-0.5, 0), LAB_root=None, channels=None,
                      full_trial_base=False):
    """
    Plot high gamma (HG) and statistics for a given subject and task using specified event.

    Parameters:
    - sub (str): The subject identifier.
    - task (str): The task identifier.
    - output_name (str): The name for the output files.
    - event (str, optional): Event name to process. Defaults to None.
    - times (tuple, optional): A tuple indicating the start and end times for processing. Defaults to (-1, 1.5).
    - base_times (tuple, optional): A tuple indicating the start and end base times for processing. Defaults to (-0.5, 0).
    - LAB_root (str, optional): The root directory for the lab. Will be determined based on OS if not provided. Defaults to None.
    - channels (list of strings, optional): The channels to plot and get stats for. Default is all channels.
    - full_trial_base (boolean): Whether to use the full trial as the baseline period. Default is False.
    This function will process the provided event for a given subject and task.
    High gamma (HG) will be computed, and statistics will be calculated and plotted.
    The results will be saved to output files.
    """
    pass

subjects = ['D0057', 'D0059', 'D0063', 'D0065', 'D0069', 'D0071']
for sub in subjects:
    sub = sub
    output_name = "stimulus_experimentStartBase1secTo101Sec"
    events = ["Stimulus"]
    times = (-1, 1.5)
    base_times = (1, 101)
    LAB_root = None
    channels = None
    full_trial_base = False

    if LAB_root is None:
        HOME = os.path.expanduser("~")
        if os.name == 'nt':  # windows
            LAB_root = os.path.join(HOME, "Box", "CoganLab")
        else:  # mac
            LAB_root = os.path.join(HOME, "Library", "CloudStorage", "Box-Box",
                                    "CoganLab")

    layout = get_data(task, root=LAB_root)
    filt = raw_from_layout(layout.derivatives['derivatives/clean'], subject=sub,
                        extension='.edf', desc='clean', preload=False)
    save_dir = os.path.join(layout.root, 'derivatives', 'freqFilt', 'figs', sub)
    if not os.path.exists(save_dir):
        os.makedirs(save_dir)

    ###

    good = crop_empty_data(filt)
    # %%

    print(f"good channels before dropping bads: {len(good.ch_names)}")
    print(f"filt channels before dropping bads: {len(filt.ch_names)}")

    good.info['bads'] = channel_outlier_marker(good, 3, 2)
    print("Bad channels in 'good':", good.info['bads'])

    filt.drop_channels(good.info['bads'])  # this has to come first cuz if you drop from good first, then good.info['bads'] is just empty
    good.drop_channels(good.info['bads'])

    print("Bad channels in 'good' after dropping once:", good.info['bads'])

    print(f"good channels after dropping bads: {len(good.ch_names)}")
    print(f"filt channels after dropping bads: {len(filt.ch_names)}")

    HG_base = get_baseline(filt, base_times)
    good.load_data()

    # If channels is None, use all channels
    if channels is None:
        channels = good.ch_names
    else:
        # Validate the provided channels
        invalid_channels = [ch for ch in channels if ch not in good.ch_names]
        if invalid_channels:
            raise ValueError(
                f"The following channels are not valid: {invalid_channels}")

        # Use only the specified channels
        good.pick_channels(channels)

    ch_type = filt.get_channel_types(only_data_chs=True)[0]
    good.set_eeg_reference(ref_channels="average", ch_type=ch_type)

    all_epochs_list = []

    for event in events:
    # Epoching and HG extraction for each specified event. Then concatenate all trials epochs objects together (do Stimulus/c25 and Stimulus/c75 for example, and combine to get all congruent trials)
        times_adj = [times[0] - 0.5, times[1] + 0.5]
        trials = trial_ieeg(good, event, times_adj, preload=True,
                            reject_by_annotation=False)
        all_epochs_list.append(trials)

    # Concatenate all trials
    all_trials = mne.concatenate_epochs(all_epochs_list)

    outliers_to_nan(all_trials, outliers=10)
    HG_ev1 = gamma.extract(all_trials, copy=False, n_jobs=1)
    crop_pad(HG_ev1, "0.5s")
    HG_ev1_rescaled = rescale(HG_ev1, HG_base, copy=True, mode='zscore')

    HG_base.decimate(2)
    HG_ev1.decimate(2)
    RTs, skipped = calculate_RTs(good)
    avg_RT = np.median(RTs)

    HG_ev1_evoke = HG_ev1.average(method=lambda x: np.nanmean(x, axis=0))
    HG_ev1_evoke_rescaled = HG_ev1_rescaled.average(method=lambda x: np.nanmean(x, axis=0))

    if event == "Stimulus":
        print('plotting stimulus')
        fig = HG_ev1_evoke_rescaled.plot(unit=False, scalings=dict(sEEG=1)) #this line is not finishing...
        print('plotted')
        for ax in fig.axes:
            ax.axvline(x=avg_RT, color='r', linestyle='--')
        print('about to save')
        fig.savefig(save_dir + '_HG_ev1_Stimulus_zscore.png')
        print('saved')
    else:
        print('about to plot if not stimulus')
        fig = HG_ev1_evoke_rescaled.plot(unit=False, scalings=dict(sEEG=1))
        print('plotted non stimulus')
        fig.savefig(save_dir + f'_HG_ev1_{output_name}_zscore.png')

    ###
    print(f"Shape of HG_ev1._data: {HG_ev1._data.shape}")
    print(f"Shape of HG_base._data: {HG_base._data.shape}")

    sig1 = HG_ev1._data
    sig2 = HG_base._data
    sig2 = make_data_same(sig2, sig1.shape)
    print(f"Shape of sig1: {sig1.shape}")
    print(f"Shape of sig2: {sig2.shape}")

    mat = time_perm_cluster(sig1, sig2, 0.05, n_jobs=6, ignore_adjacency=1)
    fig = plt.figure()
    plt.imshow(mat, aspect='auto')
    fig.savefig(save_dir + f'_{output_name}_stats.png', dpi=300)

    channels = good.ch_names

    #save channels with their indices 
    save_channels_to_file(channels, sub, task, save_dir)

    # save significant channels to a json
    save_sig_chans(f'{output_name}', mat, channels, sub, save_dir)
# Out:
# ['c:\\Users\\jz421\\Desktop\\GlobalLocal', 'C:\\Users\\jz421\\Desktop\\GlobalLocal\\IEEG_Pipelines', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\python311.zip', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\DLLs', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg', '', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\win32\\lib', 'C:\\Users\\jz421\\AppData\\Roaming\\Python\\Python311\\site-packages\\Pythonwin', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\win32', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\win32\\lib', 'c:\\Users\\jz421\\AppData\\Local\\anaconda3\\envs\\ieeg\\Lib\\site-packages\\Pythonwin', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/', 'C:/Users/jz421/Desktop/GlobalLocal/IEEG_Pipelines/']
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-01_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-01_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-01_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-02_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (163) does not match the number of channels in the raw data file (162). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-02_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-02_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-03_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (163) does not match the number of channels in the raw data file (162). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-03_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-03_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_acq-01_space-ACPC_electrodes.tsv.
# Extracting EDF parameters from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-04_desc-clean_ieeg.edf...
# EDF file detected
# Setting channel info structure...
# Creating raw.info structure...
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 228 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (163) does not match the number of channels in the raw data file (162). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# Reading events from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-04_desc-clean_events.tsv.
# Reading channel info from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_task-GlobalLocal_acq-01_run-04_desc-clean_channels.tsv.
# Reading electrode coords from C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\clean\sub-D0071\ieeg\sub-D0071_acq-01_space-ACPC_electrodes.tsv.
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Omitted 225 annotation(s) that were outside data range.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: The number of channels in the channels.tsv sidecar file (163) does not match the number of channels in the raw data file (162). Will not try to set channel names.
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# C:\Users\jz421\Desktop\GlobalLocal\IEEG_Pipelines\ieeg\io.py:113: RuntimeWarning: Cannot set channel type for the following channels, as they are missing in the raw data: Trigger
#   new_raw = read_raw_bids(bids_path=BIDS_path, verbose=verbose)
# good channels before dropping bads: 162
# filt channels before dropping bads: 162
# outlier round 1 channels: ['RTAS7']
# outlier round 1 channels: ['RTAS7', 'RTMM15']
# outlier round 2 channels: ['RTAS7', 'RTMM15', 'RFO15']
# outlier round 2 channels: ['RTAS7', 'RTMM15', 'RFO15', 'RTAS8']
# outlier round 2 channels: ['RTAS7', 'RTMM15', 'RFO15', 'RTAS8', 'RTMM16']
# Bad channels in 'good': ['RTAS7', 'RTMM15', 'RFO15', 'RTAS8', 'RTMM16']
# Bad channels in 'good' after dropping once: []
# good channels after dropping bads: 157
# filt channels after dropping bads: 157
# Reading 0 ... 6021119  =      0.000 ...  2940.000 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/n75', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/n25', 'Response/c75/n75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/n75', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/n25', 'Stimulus/c75/n75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 1 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 1 events and 206849 original time points ...
# 0 bad epochs dropped
# 100%|██████████| 1/1 [00:48<00:00, 48.73s/it]
# Reading 0 ... 4864645  =      0.000 ...  2375.315 secs...
# Applying average reference.
# Applying a custom ('sEEG',) reference.
# Used Annotations descriptions: ['Response/c25/n25', 'Response/c25/n75', 'Response/c25/r25', 'Response/c25/r75', 'Response/c25/s25', 'Response/c25/s75', 'Response/c75/n25', 'Response/c75/n75', 'Response/c75/r25', 'Response/c75/r75', 'Response/c75/s25', 'Response/c75/s75', 'Response/i25/r25', 'Response/i25/r75', 'Response/i25/s25', 'Response/i25/s75', 'Response/i75/r25', 'Response/i75/r75', 'Response/i75/s25', 'Response/i75/s75', 'Stimulus/c25/n25', 'Stimulus/c25/n75', 'Stimulus/c25/r25', 'Stimulus/c25/r75', 'Stimulus/c25/s25', 'Stimulus/c25/s75', 'Stimulus/c75/n25', 'Stimulus/c75/n75', 'Stimulus/c75/r25', 'Stimulus/c75/r75', 'Stimulus/c75/s25', 'Stimulus/c75/s75', 'Stimulus/i25/r25', 'Stimulus/i25/r75', 'Stimulus/i25/s25', 'Stimulus/i25/s75', 'Stimulus/i75/r25', 'Stimulus/i75/r75', 'Stimulus/i75/s25', 'Stimulus/i75/s75', 'experimentStart']
# Not setting metadata
# 444 matching events found
# No baseline correction applied
# 0 projection items activated
# Using data from preloaded Raw for 444 events and 7169 original time points ...
# 0 bad epochs dropped
# 100%|██████████| 444/444 [08:23<00:00,  1.13s/it]
# Applying baseline correction (mode: zscore)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\199656630.py:133: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_base.decimate(2)
# C:\Users\jz421\AppData\Local\Temp\ipykernel_5184\199656630.py:134: RuntimeWarning: The measurement information indicates a low-pass frequency of 1024.0 Hz. The decim=2 parameter will result in a sampling frequency of 1024.0 Hz, which can cause aliasing artifacts.
#   HG_ev1.decimate(2)
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# NOTE: pick_channels() is a legacy function. New code should use inst.pick(...).
# about to plot if not stimulus
# plotted non stimulus
# Shape of HG_ev1._data: (444, 157, 2561)
# Shape of HG_base._data: (1, 157, 102401)
# Shape of sig1: (444, 157, 2561)
# Shape of sig2: (39, 157, 2561)
# [Parallel(n_jobs=6)]: Using backend LokyBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done   1 tasks      | elapsed:   36.0s
# [Parallel(n_jobs=6)]: Done   2 tasks      | elapsed:   36.1s
# [Parallel(n_jobs=6)]: Done   3 tasks      | elapsed:   36.4s
# [Parallel(n_jobs=6)]: Done   4 tasks      | elapsed:   36.5s
# [Parallel(n_jobs=6)]: Done   5 tasks      | elapsed:   36.5s
# [Parallel(n_jobs=6)]: Done   6 tasks      | elapsed:   36.6s
# [Parallel(n_jobs=6)]: Done   7 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done   8 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done   9 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done  10 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done  11 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done  12 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=6)]: Done  13 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  14 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  15 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  16 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  17 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  18 tasks      | elapsed:  1.7min
# [Parallel(n_jobs=6)]: Done  19 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  20 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  21 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  22 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  23 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  24 tasks      | elapsed:  2.3min
# [Parallel(n_jobs=6)]: Done  25 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=6)]: Done  26 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  27 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  28 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  29 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  30 tasks      | elapsed:  2.9min
# [Parallel(n_jobs=6)]: Done  31 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  32 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=6)]: Done  33 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=6)]: Done  34 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=6)]: Done  35 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=6)]: Done  36 tasks      | elapsed:  3.5min
# [Parallel(n_jobs=6)]: Done  37 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  39 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  40 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  41 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  42 tasks      | elapsed:  4.0min
# [Parallel(n_jobs=6)]: Done  43 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=6)]: Done  44 tasks      | elapsed:  4.5min
# [Parallel(n_jobs=6)]: Done  45 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  46 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  47 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  48 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=6)]: Done  49 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=6)]: Done  50 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=6)]: Done  51 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=6)]: Done  52 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=6)]: Done  53 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=6)]: Done  54 tasks      | elapsed:  5.2min
# [Parallel(n_jobs=6)]: Done  55 tasks      | elapsed:  5.7min
# [Parallel(n_jobs=6)]: Done  56 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done  57 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=6)]: Done  58 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=6)]: Done  59 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=6)]: Done  60 tasks      | elapsed:  5.9min
# [Parallel(n_jobs=6)]: Done  61 tasks      | elapsed:  6.3min
# [Parallel(n_jobs=6)]: Done  62 tasks      | elapsed:  6.4min
# [Parallel(n_jobs=6)]: Done  63 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done  64 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done  65 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done  66 tasks      | elapsed:  6.5min
# [Parallel(n_jobs=6)]: Done  67 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=6)]: Done  68 tasks      | elapsed:  7.0min
# [Parallel(n_jobs=6)]: Done  69 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done  70 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done  71 tasks      | elapsed:  7.1min
# [Parallel(n_jobs=6)]: Done  72 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=6)]: Done  73 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=6)]: Done  74 tasks      | elapsed:  7.6min
# [Parallel(n_jobs=6)]: Done  75 tasks      | elapsed:  7.7min
# [Parallel(n_jobs=6)]: Done  76 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=6)]: Done  77 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=6)]: Done  78 tasks      | elapsed:  7.8min
# [Parallel(n_jobs=6)]: Done  79 tasks      | elapsed:  8.1min
# [Parallel(n_jobs=6)]: Done  80 tasks      | elapsed:  8.2min
# [Parallel(n_jobs=6)]: Done  81 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=6)]: Done  82 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=6)]: Done  83 tasks      | elapsed:  8.3min
# [Parallel(n_jobs=6)]: Done  84 tasks      | elapsed:  8.4min
# [Parallel(n_jobs=6)]: Done  85 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=6)]: Done  86 tasks      | elapsed:  8.7min
# [Parallel(n_jobs=6)]: Done  87 tasks      | elapsed:  8.8min
# [Parallel(n_jobs=6)]: Done  88 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done  89 tasks      | elapsed:  8.9min
# [Parallel(n_jobs=6)]: Done  90 tasks      | elapsed:  9.0min
# [Parallel(n_jobs=6)]: Done  91 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done  92 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=6)]: Done  93 tasks      | elapsed:  9.4min
# [Parallel(n_jobs=6)]: Done  94 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=6)]: Done  95 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=6)]: Done  96 tasks      | elapsed:  9.5min
# [Parallel(n_jobs=6)]: Done  97 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=6)]: Done  98 tasks      | elapsed:  9.8min
# [Parallel(n_jobs=6)]: Done  99 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=6)]: Done 100 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 101 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 102 tasks      | elapsed: 10.0min
# [Parallel(n_jobs=6)]: Done 103 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=6)]: Done 104 tasks      | elapsed: 10.3min
# [Parallel(n_jobs=6)]: Done 105 tasks      | elapsed: 10.4min
# [Parallel(n_jobs=6)]: Done 106 tasks      | elapsed: 10.5min
# [Parallel(n_jobs=6)]: Done 107 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=6)]: Done 108 tasks      | elapsed: 10.6min
# [Parallel(n_jobs=6)]: Done 109 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 110 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 111 tasks      | elapsed: 10.9min
# [Parallel(n_jobs=6)]: Done 112 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=6)]: Done 113 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=6)]: Done 114 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=6)]: Done 115 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=6)]: Done 116 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=6)]: Done 117 tasks      | elapsed: 11.5min
# [Parallel(n_jobs=6)]: Done 118 tasks      | elapsed: 11.6min
# [Parallel(n_jobs=6)]: Done 119 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=6)]: Done 120 tasks      | elapsed: 11.7min
# [Parallel(n_jobs=6)]: Done 121 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=6)]: Done 122 tasks      | elapsed: 11.9min
# [Parallel(n_jobs=6)]: Done 123 tasks      | elapsed: 12.0min
# [Parallel(n_jobs=6)]: Done 124 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=6)]: Done 125 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=6)]: Done 126 tasks      | elapsed: 12.2min
# [Parallel(n_jobs=6)]: Done 127 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=6)]: Done 128 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=6)]: Done 129 tasks      | elapsed: 12.5min
# [Parallel(n_jobs=6)]: Done 130 tasks      | elapsed: 12.7min
# [Parallel(n_jobs=6)]: Done 131 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=6)]: Done 132 tasks      | elapsed: 12.8min
# [Parallel(n_jobs=6)]: Done 133 tasks      | elapsed: 13.0min
# [Parallel(n_jobs=6)]: Done 134 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=6)]: Done 135 tasks      | elapsed: 13.1min
# [Parallel(n_jobs=6)]: Done 136 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=6)]: Done 137 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=6)]: Done 138 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=6)]: Done 139 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=6)]: Done 140 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=6)]: Done 141 tasks      | elapsed: 13.6min
# [Parallel(n_jobs=6)]: Done 142 tasks      | elapsed: 13.8min
# [Parallel(n_jobs=6)]: Done 143 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=6)]: Done 144 tasks      | elapsed: 13.9min
# [Parallel(n_jobs=6)]: Done 145 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=6)]: Done 146 tasks      | elapsed: 14.2min
# [Parallel(n_jobs=6)]: Done 150 out of 157 | elapsed: 14.4min remaining:   40.3s
# [Parallel(n_jobs=6)]: Done 154 out of 157 | elapsed: 14.9min remaining:   17.3s
# [Parallel(n_jobs=6)]: Done 157 out of 157 | elapsed: 15.0min finished
# Saved channel names and indices to C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\freqFilt\figs\D0071\channels_D0071_GlobalLocal.txt
# Saved significant channels for subject D0071 and mask response_experimentStartBase1secTo101Sec to C:\Users\jz421\Box\CoganLab\BIDS-1.1_GlobalLocal\BIDS\derivatives\freqFilt\figs\D0071\sig_chans_D0071_response_experimentStartBase1secTo101Sec.json
